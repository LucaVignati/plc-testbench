# %%
import soundfile as sf
import matplotlib.pyplot as plt


data, samplerate = sf.read('./soundFileData/Piano/508790__tmstu__piano-chord-2.wav')
plt.plot(data)
plt.show()
print(len(data))
# Out:
# 0.005315184593200684
